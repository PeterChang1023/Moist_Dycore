# %%
using JLD
using PyPlot

u_read = load("RH0_3_0.dat")

u      = u_read["grid_u_c_xyzt"]
v      = u_read["grid_v_c_xyzt"]
spe_vor_final_xyz = u_read["spe_vor_c_xyzt"]
grid_t_c_xyzt = u_read["grid_t_c_xyzt"]
grid_t_eq_xyzt = u_read["grid_t_eq_xyzt"]
grid_lnps_xyzt = u_read["grid_lnps_xyzt"]

grid_p_half_xyzt   = u_read["grid_p_half_xyzt"]
grid_Δp_xyzt       = u_read["grid_Δp_xyzt"] 
grid_lnp_half_xyzt = u_read["grid_lnp_half_xyzt"]
grid_p_full_xyzt   = u_read["grid_p_full_xyzt"]
grid_lnp_full_xyzt = u_read["grid_lnp_full_xyzt"]
#print((spe_vor_final_xyz))

spe_lnps_c_xyzt = u_read["spe_lnps_c_xyzt"]
spe_lnps_p_xyzt = u_read["spe_lnps_p_xyzt"]

x = range(-180,180,128)
y = range(-55, 55,64)
xx = first.(Iterators.product(x,y))
yy = last.(Iterators.product(x,y))

println(size(u))
k = 0.5*(v.^2+ u.^2)
#println(size(k[:,:,:]))
for tt in 1:3
    PyPlot.figure()
    PyPlot.contourf(xx, yy, u[:,:,1,tt])
    PyPlot.xlabel("Longitude")
    PyPlot.ylabel("Latitude")
    PyPlot.title("u wind at surface")
    PyPlot.colorbar()
    PyPlot.savefig(r"/graphs/dry_300_u/%t.png", dpi=300.)
    PyPlot.close()
end
println("over")
# Out:
# (128, 64, 20, 3)
# PyError ($(Expr(:escape, :(ccall(#= /Users/PeterChang/.julia/packages/PyCall/twYvK/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'AttributeError'>
# AttributeError("'PyCall.jlwrap' object has no attribute 'write'")
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/matplotlib/pyplot.py", line 996, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/matplotlib/figure.py", line 3328, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/matplotlib/backend_bases.py", line 2362, in print_figure
#     result = print_method(
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/matplotlib/backend_bases.py", line 2228, in <lambda>
#     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py", line 509, in print_png
#     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py", line 458, in _print_pil
#     mpl.image.imsave(
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/matplotlib/image.py", line 1687, in imsave
#     image.save(fname, **pil_kwargs)
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/PIL/Image.py", line 2431, in save
#     save_handler(self, fp, filename)
#   File "/Users/PeterChang/.julia/conda/3/aarch64/lib/python3.10/site-packages/PIL/PngImagePlugin.py", line 1307, in _save
#     fp.write(_MAGIC)
#
#
# Stacktrace:
#   [1] pyerr_check
#     @ ~/.julia/packages/PyCall/twYvK/src/exception.jl:75 [inlined]
#   [2] pyerr_check
#     @ ~/.julia/packages/PyCall/twYvK/src/exception.jl:79 [inlined]
#   [3] _handle_error(msg::String)
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/exception.jl:96
#   [4] macro expansion
#     @ ~/.julia/packages/PyCall/twYvK/src/exception.jl:110 [inlined]
#   [5] #107
#     @ ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:43 [inlined]
#   [6] disable_sigint
#     @ ./c.jl:473 [inlined]
#   [7] __pycall!
#     @ ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:42 [inlined]
#   [8] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{Regex}, nargs::Int64, kw::PyCall.PyObject)
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:29
#   [9] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{Regex}, kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol}, NamedTuple{(:dpi,), Tuple{Float64}}})
#     @ PyCall ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:11
#  [10] #pycall#113
#     @ ~/.julia/packages/PyCall/twYvK/src/pyfncall.jl:83 [inlined]
#  [11] savefig(args::Regex; kws::Base.Pairs{Symbol, Float64, Tuple{Symbol}, NamedTuple{(:dpi,), Tuple{Float64}}})
#     @ PyPlot ~/.julia/packages/PyPlot/H01LC/src/PyPlot.jl:194
#  [12] top-level scope
#     @ ./In[1]:38

# %%
using JLD
using PyPlot

u_read  = load("RH0_3_0.dat")

qv      = u_read["grid_tracers_c_xyz1t"]
p      = u_read["grid_p_full_xyzt"]
u      = u_read["grid_u_c_xyzt"]
v      = u_read["grid_v_c_xyzt"]
# qv = zeros(size(e))
# qv .= 0.622 .* e ./ (p)
print(size(qv))
#print(maximum.(qv[:,:,:,1]))
#print(maximum(p))
#print(maximum(qv))
k = 0.5*(v.^2+ u.^2)
x = range(-180,180,128)
y = range(-55, 55,64)
xx = first.(Iterators.product(x,y))
yy = last.(Iterators.product(x,y))
for t in collect(1:3)
    PyPlot.figure()
    PyPlot.contourf(xx, yy, (k[:,:,1,t]), extend="both")
    PyPlot.xlabel("Longitude")
    PyPlot.ylabel("Latitude")
    PyPlot.title("p at level 10 Day $(t) with LH")
    CB = PyPlot.colorbar()
    #PyPlot.savefig("graphs_LH/$(t)_LH.png", dpi=300.)
    #PyPlot.close_figs()
end
x = reshape(qv[:,:,:,1],128*64*20,1)
#print(size(x))
#print(sort(x, dims=1, rev=true))

println("over")
# Out:
# (128, 64, 20, 3)over
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
using JLD
using PyPlot

u_read = load("HS_test_start_from_90.dat")

u      = u_read["grid_u_c_xyzt"]
v      = u_read["grid_v_c_xyzt"]
spe_vor_final_xyz = u_read["spe_vor_c_xyzt"]
grid_t_c_xyzt = u_read["grid_t_c_xyzt"]
grid_t_eq_xyzt = u_read["grid_t_eq_xyzt"]
grid_lnps_xyzt = u_read["grid_lnps_xyzt"]

grid_p_half_xyzt   = u_read["grid_p_half_xyzt"]
grid_Δp_xyzt       = u_read["grid_Δp_xyzt"] 
grid_lnp_half_xyzt = u_read["grid_lnp_half_xyzt"]
grid_p_full_xyzt   = u_read["grid_p_full_xyzt"]
grid_lnp_full_xyzt = u_read["grid_lnp_full_xyzt"]
#print((spe_vor_final_xyz))

spe_lnps_c_xyzt = u_read["spe_lnps_c_xyzt"]
spe_lnps_p_xyzt = u_read["spe_lnps_p_xyzt"]

x = range(-180,180,128)
y = range(-55, 55,64)
xx = first.(Iterators.product(x,y))
yy = last.(Iterators.product(x,y))

println(size(u))
#println(size(k[:,:,:]))

PyPlot.contourf(xx, yy, grid_t_c_xyzt[:,:,1,3])
PyPlot.xlabel("Longitude")
PyPlot.ylabel("Latitude")
PyPlot.title("Temperature at surface on Day 90")

cb = PyPlot.colorbar()
cb[:set_label]("[K]")
#PyPlot.savefig("test_start90day.png", dpi=300.)
println("over")
# Out:
# (128, 64, 20, 3)
# over
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
using JLD
x = exp(1)
print(log(x))
# Out:
# 1.0
